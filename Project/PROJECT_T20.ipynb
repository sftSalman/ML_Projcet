# %%
import pandas as pd 
import numpy as np 
from matplotlib import pyplot as plt 
import seaborn as sns

# %%
df=pd.read_csv('Final2_T20.csv')

df =df.drop("Unnamed: 0",axis=1)

# %%
df.head()
# Out:
#    Result  Won By Run  Won By Wicket  Batting First       Team1         Team2  \
# 0       1       100.0            0.0            0.0    England      Australia
# 1       0         2.0            0.0            0.0    England      Sri Lanka
# 2       0         0.0            0.0            1.0    England       Pakistan
# 3       0        77.0            0.0            0.0  Australia        England
# 4       0        15.0            0.0            0.0    England    West Indies
#
#   Match Date  Country  Home  Away  Bowling_first  Current_ranking  \
# 0   13-06-05  England   1.0   0.0            1.0              272
# 1   15-06-06  England   1.0   0.0            1.0              272
# 2   28-08-06  England   1.0   0.0            0.0              272
# 3   09-01-07  England   0.0   1.0            1.0              272
# 4   28-06-07  England   1.0   0.0            1.0              272
#
#    Team_ranking  Batting_ranking  Bowling_ranking
# ...

# %%
df= df.drop('Won By Wicket',axis=1)
df =df.drop("Match Date",axis=1)
df =df.drop("Batting First",axis=1)
df =df.drop("Away",axis=1)
df =df.drop("Won By Run",axis=1)
df =df.drop("Home",axis=1)
df =df.drop("Bowling_first",axis=1)

# %%
conditions = [
    (df['Country'] == 'England') ,
    (df['Country'] == 'South Africa'),
    (df['Country'] == 'West Indies'),
    (df['Country'] == 'New Zealand'),
    (df['Country'] == 'India'),
    (df['Country'] == 'Pakistan'),
    (df['Country'] == 'Sri Lanka'),
    (df['Country'] == 'Zimbabwe'),
    (df['Country'] == 'Ireland'),
    (df['Country'] == 'Scotland'),
    (df['Country'] == 'Afghanistan'),
    (df['Country'] == 'Bermuda'),
    (df['Country'] == 'Netherlands'),
    (df['Country'] == 'Bangladesh'),
    (df['Country'] == 'Kenya'),
    (df['Country'] == 'Namibia'),
    (df['Country'] == 'Australia'),
]
choices = [50,55.76,46.37,53.19,64.85,62.79,46.37,23.52, 46.15,44.62,58,26.67,52.50,32.32,39.47,78.95,52.21]
df['Winning_rate'] = np.select(conditions, choices)
(df)
# Out:
#       Result         Team1         Team2      Country  Current_ranking  \
# 0          1      England      Australia      England              272
# 1          0      England      Sri Lanka      England              272
# 2          0      England       Pakistan      England              272
# 3          0    Australia        England      England              272
# 4          0      England    West Indies      England              272
# ...      ...           ...           ...          ...              ...
# 1642       1  Afghanistan    West Indies  Afghanistan              230
# 1643       1  Afghanistan    West Indies  Afghanistan              230
# 1644       1  Afghanistan        Ireland  Afghanistan              230
# 1645       1  Afghanistan        Ireland  Afghanistan              230
# 1646       0  Afghanistan        Ireland  Afghanistan              230
#
#       Team_ranking  Batting_ranking  Bowling_ranking  Winning_rate
# ...

# %%
conditions = [
    (df['Country'] == 'England') ,
    (df['Country'] == 'South Africa'),
    (df['Country'] == 'West Indies'),
    (df['Country'] == 'New Zealand'),
    (df['Country'] == 'India'),
    (df['Country'] == 'Pakistan'),
    (df['Country'] == 'Sri Lanka'),
    (df['Country'] == 'Zimbabwe'),
    (df['Country'] == 'Ireland'),
    (df['Country'] == 'Scotland'),
    (df['Country'] == 'Afghanistan'),
    (df['Country'] == 'Bermuda'),
    (df['Country'] == 'Netherlands'),
    (df['Country'] == 'Bangladesh'),
    (df['Country'] == 'Kenya'),
    (df['Country'] == 'Namibia'),
    (df['Country'] == 'Australia'),
]
choices = [167.2,164.4,156.2,165.4,167.2,154.4,154.0,146,162,155,159,120,151.4,152,146.8,164.2,168.8]
df['run_rate'] = np.select(conditions, choices)
(df)
# Out:
#       Result         Team1         Team2      Country  Current_ranking  \
# 0          1      England      Australia      England              272
# 1          0      England      Sri Lanka      England              272
# 2          0      England       Pakistan      England              272
# 3          0    Australia        England      England              272
# 4          0      England    West Indies      England              272
# ...      ...           ...           ...          ...              ...
# 1642       1  Afghanistan    West Indies  Afghanistan              230
# 1643       1  Afghanistan    West Indies  Afghanistan              230
# 1644       1  Afghanistan        Ireland  Afghanistan              230
# 1645       1  Afghanistan        Ireland  Afghanistan              230
# 1646       0  Afghanistan        Ireland  Afghanistan              230
#
#       Team_ranking  Batting_ranking  Bowling_ranking  Winning_rate  run_rate
# ...

# %%
df
# Out:
#       Result         Team1         Team2      Country  Current_ranking  \
# 0          1      England      Australia      England              272
# 1          0      England      Sri Lanka      England              272
# 2          0      England       Pakistan      England              272
# 3          0    Australia        England      England              272
# 4          0      England    West Indies      England              272
# ...      ...           ...           ...          ...              ...
# 1642       1  Afghanistan    West Indies  Afghanistan              230
# 1643       1  Afghanistan    West Indies  Afghanistan              230
# 1644       1  Afghanistan        Ireland  Afghanistan              230
# 1645       1  Afghanistan        Ireland  Afghanistan              230
# 1646       0  Afghanistan        Ireland  Afghanistan              230
#
#       Team_ranking  Batting_ranking  Bowling_ranking  Winning_rate  run_rate
# ...

# %%
corr = df.corr()
corr['Result'].sort_values(ascending=False)
# Out:
# Result             1.000000
# Winning_rate       0.316721
# run_rate           0.257037
# Current_ranking    0.254041
# Batting_ranking    0.145923
# Bowling_ranking    0.128450
# Team_ranking       0.107586
# Name: Result, dtype: float64

# %%
df['W_features'] =df['Current_ranking']*10+df['Batting_ranking']*2+df['Bowling_ranking']*1+df['Team_ranking']*.5

# %%
#df= df.drop('Current_ranking',axis=1)
#df =df.drop("Batting_ranking",axis=1)
#df =df.drop("Bowling_ranking",axis=1)
#df =df.drop("Team_ranking",axis=1)

# %%
conditions = [
    (df['Country'] == 'England') ,
    (df['Country'] == 'South Africa'),
    (df['Country'] == 'West Indies'),
    (df['Country'] == 'New Zealand'),
    (df['Country'] == 'India'),
    (df['Country'] == 'Pakistan'),
    (df['Country'] == 'Sri Lanka'),
    (df['Country'] == 'Zimbabwe'),
    (df['Country'] == 'Ireland'),
    (df['Country'] == 'Scotland'),
    (df['Country'] == 'Afghanistan'),
    (df['Country'] == 'Bermuda'),
    (df['Country'] == 'Netherlands'),
    (df['Country'] == 'Bangladesh'),
    (df['Country'] == 'Kenya'),
    (df['Country'] == 'Namibia'),
    (df['Country'] == 'Australia'),
]
choices = [433,452,448,422,576,461,490,200,348,311,369,200,327,361,200,281,579]
df['Feature_score'] = np.select(conditions, choices)
(df)
# Out:
#       Result         Team1         Team2      Country  Current_ranking  \
# 0          1      England      Australia      England              272
# 1          0      England      Sri Lanka      England              272
# 2          0      England       Pakistan      England              272
# 3          0    Australia        England      England              272
# 4          0      England    West Indies      England              272
# ...      ...           ...           ...          ...              ...
# 1642       1  Afghanistan    West Indies  Afghanistan              230
# 1643       1  Afghanistan    West Indies  Afghanistan              230
# 1644       1  Afghanistan        Ireland  Afghanistan              230
# 1645       1  Afghanistan        Ireland  Afghanistan              230
# 1646       0  Afghanistan        Ireland  Afghanistan              230
#
#       Team_ranking  Batting_ranking  Bowling_ranking  Winning_rate  run_rate  \
# ...

# %%
corr = df.corr()
corr['Result'].sort_values(ascending=False)
# Out:
# Result             1.000000
# Winning_rate       0.316721
# run_rate           0.257037
# Feature_score      0.255606
# W_features         0.254176
# Current_ranking    0.254041
# Batting_ranking    0.145923
# Bowling_ranking    0.128450
# Team_ranking       0.107586
# Name: Result, dtype: float64

# %%
plt.figure(figsize=(12,8))
sns.heatmap(df.corr(),annot=True)

# %%
df= df.drop('W_features',axis=1)

# %%
df
# Out:
#       Result         Team1         Team2      Country  Current_ranking  \
# 0          1      England      Australia      England              272
# 1          0      England      Sri Lanka      England              272
# 2          0      England       Pakistan      England              272
# 3          0    Australia        England      England              272
# 4          0      England    West Indies      England              272
# ...      ...           ...           ...          ...              ...
# 1642       1  Afghanistan    West Indies  Afghanistan              230
# 1643       1  Afghanistan    West Indies  Afghanistan              230
# 1644       1  Afghanistan        Ireland  Afghanistan              230
# 1645       1  Afghanistan        Ireland  Afghanistan              230
# 1646       0  Afghanistan        Ireland  Afghanistan              230
#
#       Team_ranking  Batting_ranking  Bowling_ranking  Winning_rate  run_rate  \
# ...

# %%
conditions = [
    (df['Country'] == 'England') ,
    (df['Country'] == 'South Africa'),
    (df['Country'] == 'West Indies'),
    (df['Country'] == 'New Zealand'),
    (df['Country'] == 'India'),
    (df['Country'] == 'Pakistan'),
    (df['Country'] == 'Sri Lanka'),
    (df['Country'] == 'Zimbabwe'),
    (df['Country'] == 'Ireland'),
    (df['Country'] == 'Scotland'),
    (df['Country'] == 'Afghanistan'),
    (df['Country'] == 'Bermuda'),
    (df['Country'] == 'Netherlands'),
    (df['Country'] == 'Bangladesh'),
    (df['Country'] == 'Kenya'),
    (df['Country'] == 'Namibia'),
    (df['Country'] == 'Australia'),
]
choices = [131,131,156.2,130,142,170,131,85,98,65,84,15,80,99,38,19,136]
df['Total_match'] = np.select(conditions, choices)
(df)
# Out:
#       Result         Team1         Team2      Country  Current_ranking  \
# 0          1      England      Australia      England              272
# 1          0      England      Sri Lanka      England              272
# 2          0      England       Pakistan      England              272
# 3          0    Australia        England      England              272
# 4          0      England    West Indies      England              272
# ...      ...           ...           ...          ...              ...
# 1642       1  Afghanistan    West Indies  Afghanistan              230
# 1643       1  Afghanistan    West Indies  Afghanistan              230
# 1644       1  Afghanistan        Ireland  Afghanistan              230
# 1645       1  Afghanistan        Ireland  Afghanistan              230
# 1646       0  Afghanistan        Ireland  Afghanistan              230
#
#       Team_ranking  Batting_ranking  Bowling_ranking  Winning_rate  run_rate  \
# ...

# %%
corr = df.corr()
corr['Result'].sort_values(ascending=False)
# Out:
# Result             1.000000
# Winning_rate       0.316721
# run_rate           0.257037
# Feature_score      0.255606
# Current_ranking    0.254041
# Total_match        0.206627
# Batting_ranking    0.145923
# Bowling_ranking    0.128450
# Team_ranking       0.107586
# Name: Result, dtype: float64

# %%
df.to_csv("Latest_T20.csv",index=False)

# %%
df=df.drop('Feature_score',axis=1)

# %%
df=df.drop('Total_match',axis=1)
df=df.drop('run_rate',axis=1)

# %%
df=df.drop('Current_ranking',axis=1)
corr = df.corr()
corr['Result'].sort_values(ascending=False)
# Out:
# Result             1.000000
# Winning_rate       0.316721
# Batting_ranking    0.145923
# Bowling_ranking    0.128450
# Team_ranking       0.107586
# Name: Result, dtype: float64

# %%
df['Team1'] = df['Team1'].astype('category')
df['Team2'] = df['Team2'].astype('category')
df['Country'] = df['Country'].astype('category')

df = pd.get_dummies(df)

# %%
X=df.drop("Result",axis=1)

# %%
y=df['Result']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=.40, random_state=42)

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc= StandardScaler()

# %%
scaled_X_train=sc.fit_transform(X_train)
scaled_X_test = sc.fit_transform(X_test)

# %%
from sklearn.svm import SVC
svc = SVC(class_weight='balanced')

# %%
from sklearn.model_selection import GridSearchCV
param_grid = {'C':[0.001,0.01,0.1,0.5,1],'gamma':['scale','auto']}
grid = GridSearchCV(svc,param_grid)
grid.fit(scaled_X_train,y_train)
# Out:
# /Users/salmanfarshi/opt/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:1978: FutureWarning: The default value of cv will change from 3 to 5 in version 0.22. Specify it explicitly to silence this warning.
#   warnings.warn(CV_WARNING, FutureWarning)
# GridSearchCV(cv='warn', error_score='raise-deprecating',
#              estimator=SVC(C=1.0, cache_size=200, class_weight='balanced',
#                            coef0=0.0, decision_function_shape='ovr', degree=3,
#                            gamma='auto_deprecated', kernel='rbf', max_iter=-1,
#                            probability=False, random_state=None, shrinking=True,
#                            tol=0.001, verbose=False),
#              iid='warn', n_jobs=None,
#              param_grid={'C': [0.001, 0.01, 0.1, 0.5, 1],
#                          'gamma': ['scale', 'auto']},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=0)

# %%
from sklearn.metrics import confusion_matrix,classification_report

# %%
grid_pred = grid.predict(scaled_X_test)

# %%
confusion_matrix(y_test,grid_pred)
# Out:
# array([[189, 148],
#        [104, 218]])

# %%
print(classification_report(y_test,grid_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.65      0.56      0.60       337
#            1       0.60      0.68      0.63       322
#
#     accuracy                           0.62       659
#    macro avg       0.62      0.62      0.62       659
# weighted avg       0.62      0.62      0.62       659

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier

# %%
models = {"Logistic Regression": LogisticRegression(),
          "KNN": KNeighborsClassifier(),
          "Random Forest": RandomForestClassifier()}


def fit_and_score(models, X_train, X_test, y_train, y_test):
   
   
    np.random.seed(42)
   
    model_scores = {}
    
    for name, model in models.items():
        
        model.fit(scaled_X_train, y_train)
       
        model_scores[name] = model.score(scaled_X_test, y_test)
    return model_scores

# %%
model_scores = fit_and_score(models=models,
                             X_train=scaled_X_train,
                             X_test=scaled_X_test,
                             y_train=y_train,
                             y_test=y_test)

model_scores
# Out:
# /Users/salmanfarshi/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /Users/salmanfarshi/opt/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# {'Logistic Regression': 0.6282245827010622,
#  'KNN': 0.5811836115326252,
#  'Random Forest': 0.5993930197268589}

# %%
train_scores = []
test_scores = []

neighbors = range(1, 21)

knn = KNeighborsClassifier()

for i in neighbors:
    knn.set_params(n_neighbors=i)
    
   
    knn.fit(X_train, y_train)
    

    train_scores.append(knn.score(X_train, y_train))
    
  
    test_scores.append(knn.score(X_test, y_test))

# %%
train_scores
# Out:
# [0.6912955465587044,
#  0.6700404858299596,
#  0.6963562753036437,
#  0.6862348178137652,
#  0.6831983805668016,
#  0.6720647773279352,
#  0.6821862348178138,
#  0.6619433198380567,
#  0.6761133603238867,
#  0.6467611336032388,
#  0.6761133603238867,
#  0.6629554655870445,
#  0.6609311740890689,
#  0.6427125506072875,
#  0.6558704453441295,
#  0.6396761133603239,
#  0.6568825910931174,
#  0.6477732793522267,
#  0.6548582995951417,
#  0.6305668016194332]

# %%
test_scores
# Out:
# [0.5766312594840668,
#  0.5584218512898331,
#  0.582701062215478,
#  0.6024279210925645,
#  0.5887708649468892,
#  0.5918057663125948,
#  0.5978755690440061,
#  0.5963581183611533,
#  0.5872534142640364,
#  0.56752655538695,
#  0.5918057663125948,
#  0.5872534142640364,
#  0.6009104704097117,
#  0.5872534142640364,
#  0.5948406676783005,
#  0.5963581183611533,
#  0.6115326251896813,
#  0.5963581183611533,
#  0.6191198786039454,
#  0.6069802731411229]

# %%
plt.plot(neighbors, train_scores, label="Train score")
plt.plot(neighbors, test_scores, label="Test score")
plt.xticks(np.arange(1, 21, 1))
plt.xlabel("Number of neighbors")
plt.ylabel("Model score")
plt.legend()

print(f"Maximum KNN score on the test data: {max(test_scores)*100:.2f}%")
# Out:
# Maximum KNN score on the test data: 61.91%

# %%
log_reg_grid = {"C": np.logspace(-4, 4, 20),
                "solver": ["liblinear"]}

# Create a hyperparameter grid for RandomForestClassifier
rf_grid = {"n_estimators": np.arange(10, 1000, 50),
           "max_depth": [None, 3, 5, 10],
           "min_samples_split": np.arange(2, 20, 2),
           "min_samples_leaf": np.arange(1, 20, 2)}

# %%
# Tune LogisticRegression
from sklearn.model_selection import RandomizedSearchCV
np.random.seed(42)

# Setup random hyperparameter search for LogisticRegression
rs_log_reg = RandomizedSearchCV(LogisticRegression(),
                                param_distributions=log_reg_grid,
                                cv=5,
                                n_iter=20,
                                verbose=True)

# Fit random hyperparameter search model for LogisticRegression
rs_log_reg.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    0.9s finished
# RandomizedSearchCV(cv=5, error_score='raise-deprecating',
#                    estimator=LogisticRegression(C=1.0, class_weight=None,
#                                                 dual=False, fit_intercept=True,
#                                                 intercept_scaling=1,
#                                                 l1_ratio=None, max_iter=100,
#                                                 multi_class='warn', n_jobs=None,
#                                                 penalty='l2', random_state=None,
#                                                 solver='warn', tol=0.0001,
#                                                 verbose=0, warm_start=False),
#                    iid='warn', n_iter=20, n_jobs=None,
# ...

# %%
rs_log_reg.best_params_
# Out:
# {'solver': 'liblinear', 'C': 78.47599703514607}

# %%
rs_log_reg.score(X_test, y_test)
# Out:
# 0.6403641881638846

# %%
np.random.seed(42)


rs_rf = RandomizedSearchCV(RandomForestClassifier(), 
                           param_distributions=rf_grid,
                           cv=5,
                           n_iter=20,
                           verbose=True)


rs_rf.fit(X_train, y_train)
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:  1.1min finished
# RandomizedSearchCV(cv=5, error_score='raise-deprecating',
#                    estimator=RandomForestClassifier(bootstrap=True,
#                                                     class_weight=None,
#                                                     criterion='gini',
#                                                     max_depth=None,
#                                                     max_features='auto',
#                                                     max_leaf_nodes=None,
#                                                     min_impurity_decrease=0.0,
#                                                     min_impurity_split=None,
#                                                     min_samples_leaf=1,
# ...

# %%
rs_rf.best_params_
# Out:
# {'n_estimators': 610,
#  'min_samples_split': 4,
#  'min_samples_leaf': 15,
#  'max_depth': 3}

# %%
rs_rf.score(X_test, y_test)
# Out:
# 0.5857359635811836

# %%
log_reg_grid = {"C": np.logspace(-4, 4, 30),
                "solver": ["liblinear"]}


gs_log_reg = GridSearchCV(LogisticRegression(),
                          param_grid=log_reg_grid,
                          cv=5,
                          verbose=True)


gs_log_reg.fit(X_train, y_train);
# Out:
# Fitting 5 folds for each of 30 candidates, totalling 150 fits
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 150 out of 150 | elapsed:    1.1s finished

# %%
gs_log_reg.best_params_
# Out:
# {'C': 62.10169418915616, 'solver': 'liblinear'}

# %%
gs_log_reg.score(X_test, y_test)
# Out:
# 0.637329286798179

# %%
from sklearn.metrics import mean_squared_log_error, mean_absolute_error

def rmsle(y_test, y_preds):
    return np.sqrt(mean_squared_log_error(y_test, y_preds))

def show_scores(model):
    train_preds = model.predict(X_train)
    test_preds = model.predict(X_test)
    scores = {"Training MAE": mean_absolute_error(y_train, train_preds),
              "Test MAE": mean_absolute_error(y_test, test_preds),
              "Training RMSLE": rmsle(y_train, train_preds),
              "Test RMSLE": rmsle(y_test, test_preds),
              "Training R^2": model.score(X_train, y_train),
              "Test R^2": model.score(X_test, y_test)}
    return scores

# %%
from sklearn.ensemble import RandomForestRegressor
model = RandomForestRegressor(n_jobs=-1,
                      random_state=42)

# %%
model.fit(X_train, y_train)
# Out:
# /Users/salmanfarshi/opt/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#                       max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=-1,
#                       oob_score=False, random_state=42, verbose=0,
#                       warm_start=False)

# %%
show_scores(model)
# Out:
# {'Training MAE': 0.31081550231168936,
#  'Test MAE': 0.41411212361325206,
#  'Training RMSLE': 0.2735252092214403,
#  'Test RMSLE': 0.3513760416020929,
#  'Training R^2': 0.38507009740778153,
#  'Test R^2': -0.027683320783410403}
